# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahnavi0-0/FMML-Projects-and-Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 14:30:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   194MB/s    in 0.4s
#
# 2024-03-31 14:30:08 (194 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2743 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 401  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 24909   1412.7689v1  Pool of knowledge available to the mankind dep...    cs
# 16565  1704.02215v2  This paper describes our approach to the SemEv...    cs
# 17395  1710.10586v1  We present Direct Assessment, a method for man...    cs
# 22755  1705.10817v1  Numerous social, medical, engineering and biol...  stat
# 19429   0909.2375v1  Fault diagnosis has become a very important ar...    cs
# ...             ...                                                ...   ...
# 22472  1608.07494v3  We improve existing instability-based methods ...  stat
# 24209   1007.0085v1  The nearest neighbor (NN) technique is very si...    cs
# 4419   1707.02432v2  Semantic segmentation was seen as a challengin...  stat
# 12043  1706.08359v1  In this paper, we present a novel massively pa...  stat
# 40800   1402.6013v1  We present OpenML and mldata, open science pla...    cs
#
#                                                    title  year  \
# 24909  Locating Tables in Scanned Documents for Recon...  2014
# 16565  EELECTION at SemEval-2017 Task 10: Ensemble of...  2017
# 17395  Evaluation of Automatic Video Captioning Using...  2017
# 22755   Dynamics Based Features For Graph Classification  2017
# 19429  Similarity Matching Techniques for Fault Diagn...  2009
# ...                                                  ...   ...
# 22472  Estimating the Number of Clusters via Normaliz...  2016
# 24209              Survey of Nearest Neighbor Techniques  2010
# 4419   Deep Semantic Segmentation for Automated Drivi...  2017
# 12043     GPU-acceleration for Large-scale Tree Boosting  2017
# 40800                   Open science in machine learning  2014
#
#                                                 keywords
# 24909  [knowledge, available, resources, documents, e...
# 16565  [describes, extracting, keyphrases, relations,...
# 17395  [assessment, assessing, automatically, generat...
# 22755  [engineering, biological, challenges, classifi...
# 19429  [diagnosis, important, advancement, mechanical...
# ...                                                  ...
# 22472  [instability, selection, normalizing, instabil...
# 24209  [technique, efficient, effective, recognition,...
# 4419   [segmentation, challenging, advancements, rela...
# 12043  [massively, algorithm, accelerating, procedure...
# 40800  [platforms, encourage, application, traditiona...
#
# [4800 rows x 6 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['keywords'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# train_df['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# train_df.groupby('tag').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['year']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'year'}, axis=1)
#               .sort_values('year', ascending=True))
#   xs = counted['year']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = train_df.sort_values('year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('tag')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='tag', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# train_df['year'].plot(kind='line', figsize=(8, 4), title='year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(train_df['tag'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(train_df, x='year', y='tag', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df['keywords']
# Out:
# 24909    [knowledge, available, resources, documents, e...
# 16565    [describes, extracting, keyphrases, relations,...
# 17395    [assessment, assessing, automatically, generat...
# 22755    [engineering, biological, challenges, classifi...
# 19429    [diagnosis, important, advancement, mechanical...
#                                ...
# 34462    [multimodal, sentiment, increasing, attention,...
# 38233    [preliminary, extraction, unsupervised, extrac...
# 28903    [intensively, correlation, algorithms, perspec...
# 2296     [optimization, objective, functions, continuou...
# 19511    [architecture, description, different, archite...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8872 words.
# Out of those 4565 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="802f7c68-3898-4f07-98f6-f32fbf031d54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("802f7c68-3898-4f07-98f6-f32fbf031d54")) {                    Plotly.newPlot(                        "802f7c68-3898-4f07-98f6-f32fbf031d54",                        [{"x":["reconstructing","conversion","tremendously","significant","detecting","counterparts","different","reproducing","available","characters","formatting","modification","thresholds","associated","concentrate","preservation","libraries","categories","experiments","performed","documents","graphical","challenging","resources","traditional","algorithm","completely","knowledge","electronic","extracting","attention","describes","publications","scientific","development","character","specifically","achieving","identified","classifier","keyphrases","convolutional","differently","keyphrase","classification","approaches","according","parameterized","relations","evaluating","techniques","automatic","generation","assessment","crowdsourcing","translation","difficult","captioning","assessors","particularly","generated","comparing","weaknesses","evaluated","presented","assessing","evaluation","automatically","challenges","organization","engineering","introduce","biological","signatures","outperform","competitive","discriminating","benchmarks","empirically","accuracies","components","established","generalized","underlying","identifies","advancement","necessary","investigating","observable","experience","complexity","identification","categorization","comprehensive","similarity","information","electrical","industries","identifying","electronics","discussed","application","mechanical","increasing","automotive","applications","diagnosis","important","appropriate","automobile","adaptation","selection","evolutionary","interaction","individual","reproduction","artificial","evolution","decoupling","decoupled","activities","convergence","properties","considerable","increases","inference","neighborhood","framework","alleviate","depression","possesses","deteriorates","eventually","estimation","consistent","universally","performance","illustrated","treatment","simulation","dimensionality","precision","simultaneously","theoretical","establish","estimates","resulting","switching","competition","purported","sociolinguistic","something","intermediate","diachronic","virtually","individuals","population","mathematical","communicative","inaccurate","traditionally","practices","popularly","extinction","contrasted","proportion","interesting","interacting","asymptotic","sophisticated","increasingly","involving","bilingual","uncovered","monolingual","scenarios","coexistence","populations","baselines","collectively","articulated","regression","recognition","separately","applicable","considered","including","preserving","significantly","operators","demonstrate","redundancy","representation","promising","computing","extensive","situations","dimensional","decomposition","especially"],"y":[17,12,2,248,88,25,754,7,309,33,2,26,13,96,6,13,12,58,544,133,70,48,270,74,198,820,29,368,29,59,171,92,7,38,135,58,173,91,38,161,4,391,13,2,527,433,112,16,89,50,379,170,148,49,19,94,155,15,2,82,170,80,11,146,182,19,257,196,122,17,55,347,36,15,102,138,10,79,62,22,105,51,79,104,28,6,70,16,25,41,222,97,20,54,153,731,7,7,80,3,55,211,7,99,8,428,40,401,86,2,49,177,62,80,132,3,132,62,1,3,30,107,210,41,43,179,15,543,21,0,11,3,13,217,85,2,914,21,37,71,57,83,119,160,54,61,150,8,31,2,2,6,36,4,3,34,51,62,4,10,14,12,3,2,7,9,83,19,16,34,54,56,8,3,10,100,2,12,60,6,15,124,375,34,53,123,242,61,247,55,562,24,369,112,118,154,52,168,71,120],"type":"bar"},{"x":["reconstructing","conversion","tremendously","significant","detecting","counterparts","diffe ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4565,), (4565, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7925

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Greedy</span> <span style=''>Search</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.8947368421052632);'>Descriptive</span> <span style=''>Spatial</span> <span style=''>Face</span> <span style=''>Features</span> <br/><br/><span style=''>Facial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expression</span> <span style='background-color:rgba(0, 255, 0, 0.5957446808510638);'>recognition</span> <span style=''>methods</span> <span style=''>use</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometric</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.9487179487179488);'>appearance</span> <span style=''>based</span> <span style=''>features</span> <span style=''>Spatial</span> <span style=''>features</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>displacements</span> <span style=''>of</span> <span style=''>facial</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>landmarks</span> <span style=''>and</span> <span style=''>carry</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometric</span> <span style='background-color:rgba(0, 255, 0, 0.31949458483754517);'>information</span> <span style=''>These</span> <span style=''>features</span> <span style=''>are</span> <span style=''>either</span> <span style=''>selected</span> <span style=''>based</span> <span style=''>on</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.42359767891682787);'>knowledge</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3989637305699482);'>dimension</span> <span style=''>reduced</span> <span style=''>from</span> <span style=''>a</span> <span style=''>large</span> <span style=''>pool</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style=''>produce</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>spatial</span> <span style=''>features</span> <span style=''>using</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style=''>facial</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>landmarks</span> <span style=''>Among</span> <span style=''>these</span> <span style=''>we</span> <span style=''>search</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.8947368421052632);'>descriptive</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>features</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>forward</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>The</span> <span style=''>chosen</span> <span style=''>feature</span> <span style=''>subset</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>facial</span> <span style='background-color:rgba(0, 255, 0, 0.48936170212765967);'>expressions</span> <span style=''>in</span> <span style=''>the</span> <span style=''>extended</span> <span style=''>Cohn</span> <span style=''>Kanade</span> <span style=''>dataset</span> <span style=''>(CK)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>delivered</span> <span style=''>887</span> <span style='background-color:rgba(0, 255, 0, 0.5957446808510638);'>recognition</span> <span style=''>accuracy</span> <span style=''>without</span> <span style=''>using</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>lp</span> <span style=''>Recovery</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Significant</span> <span style=''>Subspace</span> <span style=''>among</span> <span style=''>Multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Subspaces</span> <span style=''>with</span> <span style=''>Outliers</span> <br/><br/><span style=''>We</span> <span style=''>assume</span> <span style=''>data</span> <span style=''>sampled</span> <span style=''>from</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>d</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>spherically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>within</span> <span style=''>each</span> <span style=''>subspace</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style=''>outlier</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>spherically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>within</span> <span style=''>the</span> <span style=''>ambient</span> <span style=''>space</span> <span style=''>(for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplicity</span> <span style=''>we</span> <span style=''>may</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>uniform</span> <span style=''>on</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>unit</span> <span style=''>spheres)</span> <span style=''>We</span> <span style=''>also</span> <span style=''>assume</span> <span style=''>mixture</span> <span style=''>weights</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>We</span> <span style=''>say</span> <span style=''>that</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>is</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>if</span> <span style=''>its</span> <span style=''>mixture</span> <span style=''>weight</span> <span style=''>is</span> <span style=''>higher</span> <span style=''>than</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mixture</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>all</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>recovery</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>subspace</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3006134969325153);'>Nonlinear</span> <span style=''>Dynamic</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3006134969325153);'>nonlinear</span> <span style=''>dynamic</span> <span style=''>models</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>new</span> <span style=''>set</span> <span style=''>of</span> <span style=''>tools</span> <span style=''>capable</span> <span style=''>of</span> <span style=''>solving</span> <span style=''>problems</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>otherwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>theory</span> <span style=''>showing</span> <span style=''>this</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>for</span> <span style=''>models</span> <span style=''>with</span> <span style=''>long</span> <span style=''>range</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>motion</span> <span style=''>capture</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.38007380073800734);'>dimensional</span> <span style=''>video</span> <span style=''>data</span> <span style=''>yielding</span> <span style=''>results</span> <span style=''>superior</span> <span style=''>to</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternatives</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximation</span> <span style=''>using</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sketching</span> <br/><br/><span style=''>Deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>powerful</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>that</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>many</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>speech</span> <span style=''>and</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>question</span> <span style=''>that</span> <span style=''>arises</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style=''>deep</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>target</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>can</span> <span style=''>we</span> <span style=''>design</span> <span style=''>a</span> <span style=''>smaller</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>network</span> <span style=''>The</span> <span style=''>question</span> <span style=''>is</span> <span style=''>in</span> <span style=''>part</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>(compression)</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>as</span> <span style=''>the</span> <span style=''>ever</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>storage</span> <span style=''>and</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>of</span> <span style=''>these</span> <span style=''>networks</span> <span style=''>pose</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>resource</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13082437275985664)
# 	representation (0.13225806451612904)
# 	segmentation (0.07096774193548387)
# 	knowledge (0.13189964157706094)
# 	processing (0.11541218637992831)
# 	detection (0.12043010752688173)
# 	information (0.26200716845878136)
# 	different (0.27025089605734764)
# 	recognition (0.13440860215053763)
# 	convolutional (0.14014336917562725)
#
# Some Statistics words are:
# 	stochastic (0.12686567164179105)
# 	algorithm (0.3835820895522388)
# 	estimation (0.17213930348258707)
# 	theoretical (0.1572139303482587)
# 	variables (0.1417910447761194)
# 	statistical (0.16119402985074627)
# 	distribution (0.18358208955223881)
# 	dimensional (0.18606965174129353)
# 	inference (0.19054726368159203)
# 	regression (0.1771144278606965)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f67a08d4-42c9-427a-9808-14ad02860980" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f67a08d4-42c9-427a-9808-14ad02860980")) {                    Plotly.newPlot(                        "f67a08d4-42c9-427a-9808-14ad02860980",                        [{"x":["reconstructing","conversion","tremendously","significant","detecting","counterparts","different","reproducing","available","characters","formatting","modification","thresholds","associated","concentrate","preservation","libraries","categories","experiments","performed","documents","graphical","challenging","resources","traditional","algorithm","completely","knowledge","electronic","extracting","attention","describes","publications","scientific","development","character","specifically","achieving","identified","classifier","keyphrases","convolutional","differently","keyphrase","classification","approaches","according","parameterized","relations","evaluating","techniques","automatic","generation","assessment","crowdsourcing","translation","difficult","captioning","assessors","particularly","generated","comparing","weaknesses","evaluated","presented","assessing","evaluation","automatically","challenges","organization","engineering","introduce","biological","signatures","outperform","competitive","discriminating","benchmarks","empirically","accuracies","components","established","generalized","underlying","identifies","advancement","necessary","investigating","observable","experience","complexity","identification","categorization","comprehensive","similarity","information","electrical","industries","identifying","electronics","discussed","application","mechanical","increasing","automotive","applications","diagnosis","important","appropriate","automobile","adaptation","selection","evolutionary","interaction","individual","reproduction","artificial","evolution","decoupling","decoupled","activities","convergence","properties","considerable","increases","inference","neighborhood","framework","alleviate","depression","possesses","deteriorates","eventually","estimation","consistent","universally","performance","illustrated","treatment","simulation","dimensionality","precision","simultaneously","theoretical","establish","estimates","resulting","switching","competition","purported","sociolinguistic","something","intermediate","diachronic","virtually","individuals","population","mathematical","communicative","inaccurate","traditionally","practices","popularly","extinction","contrasted","proportion","interesting","interacting","asymptotic","sophisticated","increasingly","involving","bilingual","uncovered","monolingual","scenarios","coexistence","populations","baselines","collectively","articulated","regression","recognition","separately","applicable","considered","including","preserving","significantly","operators","demonstrate","redundancy","representation","promising","computing","extensive","situations","dimensional","decomposition","especially","requiring","benchmark","parameters","simplifying","connected","compression","deployment","researchers","compressed","trajectory","observations","technique","computation","recovering","conditional","fundamental","characteristics","contextual","trajectories","generates","providing","byproduct","represent","minimized","coordinate","constrain","quantitatively","measurements","egomotion","predicted","combination","likelihood","occlusion","obstacles","egocentric","interactions","plausible","predictive","foreground","relationship","localization","differences","practical","interpolate","therefore","structural","abstracts","implications","effective","empirical","definitions","landscapes","confirmed","probabilities","introduced","perspective","h ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	depression
# 	regressionclassification
# 	specialize
# 	combinatorics
# 	detectability
# 	confounded
# 	semiparametric
# 	covariates
# 	scientist
# 	matchings
# 	particulars
# 	panoramic
# 	interrelated
# 	invertibility
# 	orthonormal
# 	supersparse
# 	hypergraph
# 	repeatmulti
# 	identifiability
# 	diminished
# Some words which never appear in Statistics papers:
# 	formatting
# 	keyphrases
# 	keyphrase
# 	assessors
# 	advancement
# 	electronics
# 	automotive
# 	automobile
# 	reproduction
# 	sociolinguistic
# 	diachronic
# 	communicative
# 	extinction
# 	coexistence
# 	articulated
# 	egomotion
# 	obstacles
# 	egocentric
# 	aesthetic
# 	substrate

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.080240258740182e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
